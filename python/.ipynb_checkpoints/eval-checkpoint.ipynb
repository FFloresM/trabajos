# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# # 1

# %%
def inversa():
    while 1:
        filas = []
        for i in range(3):
            fila = input("ingrese elementos fila {}: ".format(1+i))
            fila = fila.split()
            fila = list(map(int, fila))
            filas.append(fila)
        A = np.array((filas[0],filas[1], filas[2]))
        det = np.linalg.det(A)
        if det == 0:
            print("matriz singular")
        else:
            break
    b = input("ingrese terminos de b: ")
    b = b.split()
    b = np.array(list(map(int, fila)))
    x = np.linalg.solve(A,b)
    return x

# %%
inversa()
# Out:
# ingrese elementos fila 1: 1 2 3
# ingrese elementos fila 2: 4 5 6
# ingrese elementos fila 3: 7 8 9
# ingrese terminos de b: 1 2 3
# array([-14.33333333,  22.66666667,  -8.        ])

# %% [markdown]
# # 2

# %%
x = np.arange(0,5,0.0001)
f = np.cos(5*x+10)
g = np.exp(-(x/3))
idx = np.argwhere(np.diff(np.sign(f - g))).flatten()
plt.plot(x,f,'b-', x,g, 'g-', x[idx],f[idx],'ro')
plt.show()

# %% [markdown]
# # 3

# %%
def sistemaN():
    while 1:
        n = int(input("ingrse n: "))
        A = np.zeros((n,n))
        b = np.zeros(n)
        for i in range(n):
            for j in range(n):
                A[i,j] = 20-2*np.cos(3*i)+3*np.sin(3*j)
        for i in range(n):
            b[i] = sum(A[i])
        if np.linalg.det(A) == 0:
            print("matriz singular")
        else:
            x = np.linalg.solve(A,b)
            break
    N = [i for i in range(1,n+1)]
    plt.scatter(x,N)
    plt.plot(x,N)
    plt.show()

# %%
sistemaN()
# Out:
# ingrse n: 30
# matriz singular
# ingrse n: 31
# matriz singular
# ingrse n: 32
# matriz singular
# ingrse n: 33
# matriz singular
# ingrse n: 34
# matriz singular
# ingrse n: 35
# matriz singular
# ingrse n: 36
# matriz singular
# ingrse n: 37
# matriz singular
# ingrse n: 38
# matriz singular
# ingrse n: 39
# matriz singular
# ingrse n: 99
# matriz singular
# ingrse n: 65
# matriz singular
# ingrse n: 43
# matriz singular
# ingrse n: 6
